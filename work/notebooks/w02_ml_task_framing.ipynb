# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/yousefwerida28/Flyrank-ML-intern/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# Clustering,Because you are not predicting a known label.
#
# You want the algorithm to look at pages and discover groups of pages that behave similarly.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# Tere is no prediction or target because it's unsupervised ML

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# Silhouette score to assess cluster separation.Whether the resulting clusters have distinct, interpretable characteristics that support different content actions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
# **One row = one page.**

# %%
import os

REPO_URL = "https://github.com/yousefwerida28/Flyrank-ML-intern.git"
REPO_DIR = "Flyrank-ML-intern"

if not os.path.isdir(REPO_DIR):
    # !git clone $REPO_URL

os.chdir(REPO_DIR)

print("Working directory:", os.getcwd())
# Out:
# Cloning into 'Flyrank-ML-intern'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 145 (delta 55), reused 92 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (145/145), 1.85 MiB | 7.04 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# Working directory: /content/Flyrank-ML-intern

# %%
import os

print(os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# True

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Dataset loaded:", df.shape)
# Out:
# Dataset loaded: (30000, 44)

# %%
lane3_df = df[
    [
        "content_id",
        "impressions_90d",
        "clicks_90d",
        "sessions_90d",
        "ctr",
        "avg_position",
        "engagement_rate",
        "word_count",
        "content_type",
        "content_age_days"
    ]
]

lane3_df.head()
# Out:
#              content_id  impressions_90d  clicks_90d  sessions_90d   ctr  \
# 0  content_304f48230142             3803          29            17  0.76
# 1  content_a1fb4e703a9e            15320           7             9  0.05
# 2  content_9aa793d4d895            12581          11            11  0.09
# 3  content_331d6c4de07b            11751          58            78  0.49
# 4  content_d99b7a2d90ca            19140          24           145  0.13
#
#    avg_position  engagement_rate  word_count     content_type  \
# 0          10.6             5.88      3221.0  keyword article
# 1          20.3             0.00      2481.0  keyword article
# 2          36.5             0.00      3515.0  keyword article
# 3           6.2             1.28         NaN  keyword article
# 4          44.0             0.00      2803.0  keyword article
#
#    content_age_days
# 0               187
# 1               445
# 2               141
# 3               463
# 4               263

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A fixed rule would require manually defining thresholds for several metrics and may miss combinations of characteristics that form meaningful groups. Clustering can consider multiple signals simultaneously and discover groups without predefined labels.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
